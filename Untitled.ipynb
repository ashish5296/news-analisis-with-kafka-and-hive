# %%
from newsapi import NewsApiClient
# from kafka import KafkaProducer
from datetime import datetime
from textblob import TextBlob
import json

# %%
# API key for News API
news_api_key = "8b331c71e2294e45bfae1d93054177df"

# Initialize News API client
newsapi = NewsApiClient(api_key=news_api_key)

# %%
# Parameters
query = "Nvidia"
start_date = "2024-12-01"
end_date = "2024-12-09"

# %%
# Fetch news articles
news_articles = newsapi.get_everything(
    q=query,
    from_param=start_date,
    to=end_date,
    language="en",
    sort_by="relevancy"
)

# %%
# Process and send articles
for article in news_articles['articles']:
    published_date = datetime.strptime(article['publishedAt'], "%Y-%m-%dT%H:%M:%SZ").strftime('%Y-%m-%d')
    message = {
        "date": published_date,
        "source": article['source']['name'],
        "title": article['title'],
        "description": article['description'] or "No description provided",
        "polarity": TextBlob(article['description'] or "").sentiment.polarity # Polarity ranges from -1 (negative) to 1 (positive)
    }
    print(f"Sent to Kafka (news-topic): {message}")
# Out:
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': '[Removed]', 'title': '[Removed]', 'description': '[Removed]', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'The Verge', 'title': 'China opens an antitrust investigation into Nvidia', 'description': 'Chinese regulators are investigating Nvidia over antitrust violations related to the company’s acquisition of Mellanox, a network hardware company with tech vital to AI chips.', 'polarity': 0.03333333333333333}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'Yahoo Entertainment', 'title': 'Forza Motorsport on PC is getting an enhanced lighting upgrade', 'description': 'Gearheads, rejoice! Forza Motorsport for PC is getting a graphics update on Monday that adds a new realistic lighting system to the game. Nvidia announced that Ray-Traced Global Illumination (RTGI) will be part of the PC-only upgrade for Turn 10’s driving sim…', 'polarity': -0.02424242424242426}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Business Insider', 'title': "TikTok owner ByteDance is now China's biggest buyer of Nvidia chips as it seeks to lead AI race, report says", 'description': 'ByteDance is the top buyer of Nvidia AI chips inside China, despite US regulations that require the sale of less powerful Nvidia chips in the country.', 'polarity': 0.2111111111111111}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': '[Removed]', 'title': '[Removed]', 'description': '[Removed]', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': '[Removed]', 'title': '[Removed]', 'description': '[Removed]', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'Business Insider', 'title': "Amazon's AI chip executive tells BI why Nvidia is not a competitor, how Anthropic helps, and what AMD needs", 'description': "Amazon's AI chip strategy focuses on customer choice, not competing directly with Nvidia.", 'polarity': 0.1}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Business Insider', 'title': 'AMD downgraded after BI report on weak demand for its AI chips among AWS customers', 'description': 'Bank of America downgraded AMD on Monday, citing competitive risks in the AI market from Nvidia and low demand impacting growth potential.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Business Insider', 'title': 'Silicon and supercomputers will define the next AI era. AWS just made a big bet on both.', 'description': 'AWS unveiled a new line of its own AI chips and plans for a supercomputer at its Re: Invent conference, signalling a shift away from Nvidia.', 'polarity': 0.36818181818181817}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Business Insider', 'title': 'Nvidia shares drop as China opens antimonopoly probe into US chip giant', 'description': "The State Administration for Market Regulation's probe is reportedly related to Nvidia's acquisition of Mellanox Technologies in 2020.", 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': '[Removed]', 'title': '[Removed]', 'description': '[Removed]', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Yahoo Entertainment', 'title': 'China targets Nvidia with antitrust probe, escalating US chip tensions', 'description': 'No description provided', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'Slashdot.org', 'title': "Elon Musk's xAI Plans Massive Expansion of AI Supercomputer in Memphis", 'description': "An anonymous reader shared this report from Reuters:\nElon Musk's artificial intelligence startup xAI plans to expand its Memphis, Tennessee, supercomputer to house at least one million graphics processing units (GPUs), the Greater Memphis Chamber said on Wedn…", 'polarity': -0.1333333333333333}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'MacRumors', 'title': "Apple Uses Amazon's Custom AI Chips for Search Services", 'description': "Apple uses custom Trainium and Graviton artificial intelligence chips from Amazon Web Services for search services, Apple machine learning and AI director Benoit Dupin said today at the AWS re:Invent conference (via CNBC).\n\n\n\n\n\nDupin said that Amazon's AI chi…", 'polarity': -0.6}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': '[Removed]', 'title': '[Removed]', 'description': '[Removed]', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'Dstack.ai', 'title': 'Exploring inference memory saturation effect: H100 vs. MI300x', 'description': 'This benchmark explores how GPU memory saturation affects LLM inference performance and cost, comparing NVIDIA H100 and AMD MI300x.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-01', 'source': '[Removed]', 'title': '[Removed]', 'description': '[Removed]', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Wired', 'title': '36 Best Cyber Monday Laptop Deals (2024), MacBooks Included', 'description': "Time to upgrade your rig? Take advantage of these Cyber Monday laptop deals on our favorite models, whether it's a MacBook, gaming laptop, or Chromebook.", 'polarity': 0.5}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Gizmodo.com', 'title': 'Intel’s Battlemage May Help Make GPUs Affordable Again', 'description': 'Intel confirmed it will share more news of what everyone expects is its long-rumored Battlemage GPU to finally compete against Nvidia and AMD.', 'polarity': 0.3}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Yahoo Entertainment', 'title': 'NVIDIA Corporation (NVDA) Among the Best Stocks to Buy For Long Term Growth According to This Indicator', 'description': 'No description provided', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'CNET', 'title': 'This Top-Rated Affordable Acer Gaming Laptop Is Even Better at $500 Off', 'description': 'The Acer Nitro 16 is already one of the best laptops for gamers on a budget, and right now you can pick it up for under $1,000.', 'polarity': 0.6428571428571428}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'MacRumors', 'title': "Intel CEO Pat Gelsinger Retires Amid Company's Decline", 'description': "Intel CEO Pat Gelsinger has retired following a challenging tenure marked by the company's struggles to compete against Apple and other major chipmakers.\n\n\n\n\n\nIntel today announced that Gelsinger, who served as the company's CEO since early 2021, officially s…", 'polarity': 0.10625}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Windows Central', 'title': "Intel just announced its Battlemage GPUs, and I can't decide if I'm more excited about the performance or prices", 'description': 'Intel just announced a pair of desktop GPUs that promise to deliver 1440p gaming at a more affordable price than competing graphics from NVIDIA and AMD.', 'polarity': 0.5}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'Windows Central', 'title': 'The coolest mobile gaming controller has a transparent design and Hall Effect sticks', 'description': 'The GameSir X3 Pro is combines advanced cooling technology and a transparent design to make a seriously neat looking controller for Xbox Cloud Gaming and Nvidia GeForce Now.', 'polarity': 0.033333333333333354}
# Sent to Kafka (news-topic): {'date': '2024-12-07', 'source': 'Digital Trends', 'title': 'It’s finally time to stop ignoring Intel GPUs', 'description': "Intel is releasing its second generation of discrete graphics cards next week. Here's why you should keep an eye on them.", 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-08', 'source': 'Slashdot.org', 'title': 'Small AI Chip Maker Marvell is Now More Valuable Than Intel', 'description': 'This year Marvell\'s stock rose 95%, giving it a $100 billion market capitalization, according to the Wall Street Journal. \n\n"The latest gains have even put Marvell\'s market cap ahead of much-beleaguered Intel, which still generates 10 times as much annual rev…', 'polarity': 0.43333333333333335}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Business Insider', 'title': 'Oracle stock is set for its best year since the dot-com boom after a 75% surge', 'description': 'Oracle shares have roughly tripled from their late-2022 low, making the cloud-computing specialist more valuable than Costco or Netflix.', 'polarity': 0.13333333333333333}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'Business Insider', 'title': "Amazon isn't seeing enough demand for AMD's AI chips to offer them via its cloud", 'description': "AWS has not committed to offer access to AMD's AI chips. That's partly because cloud customers aren't asking for these components.", 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Digital Trends', 'title': 'AMD’s new GPU breaks cover in online calculator', 'description': "A listing for AMD's unannounced RX 8800 XT has appeared online, and it includes some big hints about the GPU.", 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': '9to5Mac', 'title': 'Apple is the best-managed company in the US, ranking claims', 'description': 'Apple is the best-run company in the United States, according to this year’s Management Top 250 ranking from the Drucker Institute. Apple dethroned Microsoft for the title, which had held it for the past four years. Microsoft slipped to third place this year,…', 'polarity': 0.08333333333333333}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Yahoo Entertainment', 'title': 'Nvidia, flush with cash, looks to acquire new talent through mergers and acquisitions', 'description': 'No description provided', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'Business Insider', 'title': "Intel says its 'no wafer left behind' days are over", 'description': "Now, Intel needs to focus on efficiency, the company's chief global operations officer said on Wednesday.", 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-01', 'source': '[Removed]', 'title': '[Removed]', 'description': '[Removed]', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Business Insider', 'title': 'Meet 2 chip execs reportedly in the running for Intel CEO — one is an outsider', 'description': 'The chipmaker is considering at least two people outside the company to replace former CEO Pat Gelsinger, who abruptly retired on Sunday.', 'polarity': -0.10625}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'GameSpot', 'title': 'Forza Motorsport Is About To Get Much Better Looking, If You Have The Hardware For It', 'description': "Nvidia has revealed that Forza Motorsport will be getting a new PC-only update on December 9 that adds ray-traced global illumination lighting (RTGI) to further enhance the game's already-stunning visuals.Basically, RTGI uses existing illumination technology …", 'polarity': -0.06590909090909092}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Rock Paper Shotgun', 'title': 'Battlemage lives: Intel announce the Arc B580 and B570 graphics cards', 'description': 'Well slap my backplate and call me CUDA, because not only are Intel’s Arc Battlemage graphics cards not dead – having once been mired in production trouble rumours – but they’ve got names and are out from next week. The CPU makers’ second batch of dedicated g…', 'polarity': -0.02}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Quartz India', 'title': 'China is going after Nvidia', 'description': 'Nvidia (NVDA) is under investigation for allegedly violating anti-monopoly laws in China.Read more...', 'polarity': 0.2}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Time', 'title': 'Intel CEO Pat Gelsinger Retires', 'description': 'Intel CEO Pat Gelsinger has retired, with David Zinsner and Michelle Johnston Holthaus named as interim co-CEOs.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Pinecone.io', 'title': 'Cascading retrieval: Unifying dense and sparse vector embeddings with reranking', 'description': 'New cascading retrieval capabilities make it seamless to combine dense retrieval and sparse retrieval and reranking into a unified search pipeline, delivering unparalleled precision, performance, and ease of use.', 'polarity': 0.11818181818181818}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Windows Central', 'title': 'Intel renamed Arc Control to the most boring thing possible, but the update adds useful features for Battlemage GPUs', 'description': "Intel's new Battlemage GPUs aren't the only new thing on the way. The Arc Control app has been renamed and updated with some new features and controls.", 'polarity': 0.10227272727272727}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Gizmodo.com', 'title': 'Intel Claims Its ‘Battlemage’ GPU Beats Nvidia’s Midrange Cards at Just $250', 'description': 'Intel’s Arc Battlemage lineup includes the B580 and B570 with up to 12 GB of memory for budget-conscious gamers.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'Digital Trends', 'title': 'You need an RTX 4090 to play this game at max settings — AMD isn’t even listed', 'description': 'The upcoming\xa0Indiana Jones and the Great Circle is releasing on December 9, and Bethesda has just shared the hardware requirements for the game. What are we dealing with? Well, to say that you’ll need one of the would be an understatement. If you want to play…', 'polarity': 0.2}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'XDA Developers', 'title': 'Valve may be working on a direct competitor to the Nvidia Shield', 'description': 'The Steam Deck 2 remains elusive.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Phoronix', 'title': 'Intel Announces Arc B-Series "Battlemage" Discrete Graphics with Linux Support', 'description': 'Succeeding the Intel Arc Graphics discrete graphics cards that launched two years ago as the DG2/Alchemist series, the next-gen Battlemage graphics cards are being announced today.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-01', 'source': '[Removed]', 'title': '[Removed]', 'description': '[Removed]', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-08', 'source': 'Android Central', 'title': "Without saying it, Google confirmed Android 16 and 17 won't offer any new and fantastic features", 'description': 'Adding support for two more versions of Android to the Pixel 6 means most new features will be locked behind the Pixel paywall.', 'polarity': 0.18409090909090906}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'Yahoo Entertainment', 'title': "Meet the Next AI Darling That Citron Research's Andrew Left Says Can Double. Nvidia Is an Investor and Not a Single Wall Street Analyst Covers the Stock.", 'description': 'No description provided', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Quartz India', 'title': 'Jeff Bezos is betting millions on a Nvidia rival', 'description': 'Billionaire Jeff Bezos is throwing his weight behind a computing company that’s coming for Nvidia’s (NVDA) dominance of the artificial intelligence chip market.Read more...', 'polarity': -0.16666666666666666}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Daringfireball.net', 'title': '★ Andy Grove Was Right', 'description': 'Grove’s words don’t read merely as advice\u2009—\u2009they read today as a postmortem for what happed to Intel over the last 20 years.', 'polarity': -0.25}
# Sent to Kafka (news-topic): {'date': '2024-12-01', 'source': 'Yahoo Entertainment', 'title': 'The best Cyber Monday laptop deals for 2024: Save on notebooks from Apple, Microsoft, Lenovo and more', 'description': 'While most Cyber Monday sales are just extensions of discounts from Black Friday, they still present a good opportunity to grab a solid notebook at a decent price. To help you avoid wasting cash, we’ve researched reviews, checked price histories and rounded u…', 'polarity': 0.19999999999999998}
# Sent to Kafka (news-topic): {'date': '2024-12-08', 'source': 'Windows Central', 'title': 'Indiana Jones and the Great Circle gets its first patch on Xbox and PC, with a nice feature for those of you with particularly beefy NVIDIA GPUs', 'description': 'Ray Tracing and bug fixes arrive for Indiana Jones and the Great Circle, which is available now in early access on Xbox and PC.', 'polarity': 0.4333333333333334}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Windows Central', 'title': 'Microsoft AI CEO predicts AGI within 7 years, but not with \'current hardware\' as indicated by Sam Altman: "I don’t think it can be done on [Nvidia] GB200s"', 'description': 'Microsoft AI CEO Mustafa Suleyman talks about AGI, security, OpenAI partnership, copyright infringement by AI, and more in a detailed interview with The Verge.', 'polarity': 0.45}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'XDA Developers', 'title': "This $100 discount on an RTX 4070 Ti Super won't last much longer", 'description': 'No description provided', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'Windows Central', 'title': "NVIDIA's RTX 4060 is aging horribly as Indiana Jones and the Great Circle Nazi-punches your VRAM", 'description': "Indiana Jones and the Great Circle is a gorgeous game that isn't easy on the PC hardware, and the RTX 4060's 8GB of VRAM is an issue.", 'polarity': 0.38333333333333336}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Gizmodo.com', 'title': 'Cheaper Than The 55″, The 65″ LG C3 OLED TV Is at a Record Low Price For Cyber Monday', 'description': 'The C3 model is a fantastic OLED TV available at a reasonable price.', 'polarity': 0.3333333333333333}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Digital Trends', 'title': 'Intel announces sudden departure of CEO amid financial turmoil', 'description': "Intel has announced that its CEO Pat Gelsinger will retire after less than four years as the company's head executive.", 'polarity': -0.16666666666666666}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Digital Trends', 'title': 'A PC ‘recession’ could make hardware way more expensive, says researcher', 'description': 'Proposed tariffs on China and Mexico could lead to a PC market recession, according to a GPU market researcher.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'Digital Trends', 'title': 'Get Copilot+ features for less with this Asus laptop deal', 'description': "The Asus ProArt P16 laptop is a powerful PC packed with great Copilot features which are perfect for all your working needs. It's on sale right now.", 'polarity': 0.5964285714285714}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Digital Trends', 'title': 'The Lenovo Legion 5i with RTX 4060 is 37% off for Cyber Week', 'description': "The Lenovo Legion 5i is a great option for anyone seeking a gaming laptop. It's currently on sale now at Lenovo and it has some great hardware.", 'polarity': 0.5333333333333333}
# Sent to Kafka (news-topic): {'date': '2024-12-08', 'source': 'Omgubuntu.co.uk', 'title': 'OBS Studio Update Adds New Features, Drops 22.04 Support', 'description': 'For high-quality screen recording and streaming few apps comes close to the power and versatility as the cross-platform and open-source OBS Studio – and a new version is out. OBS Studio 31.0 intros a slate of new features and capabilities. Among them, the lon…', 'polarity': 0.024242424242424232}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Windows Central', 'title': 'Indiana Jones and the Great Circle PC system requirements and specs: Can you run it?', 'description': "The highly anticipated Indiana Jones and the Great Circle is almost here, but does your PC meet its system requirements? How about the recommended specs? Here's what you need to know.", 'polarity': 0.48000000000000004}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'R-bloggers.com', 'title': 'Quantitative Analysis: NVIDIA', 'description': 'Although the investors do not like the pace of revenue growth, in terms of QoQ, NVIDIA’s revenue increased for the first time in five quarters. Source code:\nContinue reading: Quantitative Analysis: NVIDIA', 'polarity': 0.25}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'Techmeme.com', 'title': "Amazon, AMD, and others are beginning to offer credible alternatives to Nvidia's AI chips, especially for inferencing, which is becoming increasingly important (Don Clark/New York Times)", 'description': "Don Clark / New York Times:\nAmazon, AMD, and others are beginning to offer credible alternatives to Nvidia's AI chips, especially for inferencing, which is becoming increasingly important\xa0 —\xa0 Amazon's new Trainium 2 chips are set to ramp up competition with N…", 'polarity': 0.25378787878787873}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Quartz India', 'title': "Apple, Nvidia, and Microsoft are America's best-managed companies right now, report says", 'description': 'Apple (AAPL) is the best-managed company in the U.S., according to a new ranking by The Wall Street Journal.Read more...', 'polarity': 0.3181818181818182}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Yahoo Entertainment', 'title': 'Bezos Backs AI Chipmaker Vying With Nvidia at $2.6 Billion Value', 'description': '(Bloomberg) -- Amazon.com Inc. founder Jeff Bezos joined Samsung in a $700 million bet on Tenstorrent, valuing the AI chip startup with ambitions of taking...', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': '9to5Mac', 'title': 'Intel’s CEO shakeup is an Apple silicon success story in a big way', 'description': 'It hasn’t been a great season for Intel, and now its CEO Pat Gelsinger is out. And in the midst of the chipmaker’s transitionary period, Apple silicon is looking like a bigger win than ever for Apple.\n\n\n\n more…', 'polarity': 0.5333333333333333}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Business Insider', 'title': 'Nvidia stock drops as China probes the chipmaker over potential antitrust violations', 'description': "China officials said they're looking into Nvidia's acquisition of chip designer Mellanox, which Nvidia purchased for nearly $7 billion five years ago.", 'polarity': 0.1}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'Quartz India', 'title': "The 'smartest' ChatGPT, Bezos bets on a Nvidia rival, and Amazon's new chip: AI news roundup", 'description': 'OpenAI kicked off its “12 Days of OpenAI” on Thursday by announcing the full version of its o1 model which it called the “smartest model in the world.”Read more...', 'polarity': 0.425}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Quartz India', 'title': 'Nvidia stock falls almost 3% as it faces an antitrust probe in China', 'description': 'Nvidia’s (NVDA) shares fell by almost 3% during mid-day trading on Monday after the Chinese government announced an investigation into the chipmaker. Fellow chipmakers Advanced Micro Devices (AMD) and Marvell (MRVL) also saw their shares fall by 4.4% and 5.2%…', 'polarity': 0.2}
# Sent to Kafka (news-topic): {'date': '2024-12-07', 'source': 'Quartz India', 'title': "Ozempic curbs drinking, Hawk Tuah's memecoin, Bezos bets on Nvidia rival: The week's most popular stories", 'description': 'Another study suggests that weight-loss meds like Wegovy (NVO) and Mounjaro (LLY) can help people cut back on drinking alcohol. Read more...', 'polarity': 0.25}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'Forbes', 'title': 'Sell Nvidia, Buy Intel Stock?', 'description': 'The stock remains down by about 50% year-to-date and has a market cap of a mere $100 billion.', 'polarity': -0.3277777777777778}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': "Tom's Hardware UK", 'title': 'Nvidia bids goodbye to GeForce Experience — Nvidia App officially replaces it in the latest driver update', 'description': "The GeForce Experience app won't receive updates anymore.", 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Windows Central', 'title': 'Path of Exile 2 PC system requirements and specs: Can you run this hack and slash RPG?', 'description': 'The long-awaited Path of Exile 2 releases into Early Access soon. Check to see if your rig can handle the PC requirements.', 'polarity': 0.1}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Yahoo Entertainment', 'title': 'Intel CEO Gelsinger retires; Zinsner and Johnston Holthaus named interim co-CEOs', 'description': 'Intel CEO CEO Pat Gelsinger has retired, with David Zinsner and Michelle Johnston Holthaus named as interim Co-CEOs.  Intel said Monday that it will conduct ...', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'GameSpot', 'title': 'Will Indiana Jones And The Great Circle Run On Your PC? Check Out The Requirements', 'description': "Indiana Jones and the Great Circle is just a few days away from launch, and Bethesda has now revealed the game's PC specs ahead of the game's December 6 early access period and December 9 launch.The game is also launching on Xbox Series X, but naturally, PC p…", 'polarity': -0.05714285714285715}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Gizmodo.com', 'title': 'Pat Gelsinger Suddenly Retires After Three Rough Years as Intel CEO', 'description': "Intel's stock price has seen better days, but Pat Gelsinger has also led the company through numerous scandals involving its latest processors.", 'polarity': 0.3333333333333333}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Forbes', 'title': 'China Probes Nvidia Stock For Antitrust Violations', 'description': "Nvidia stock is under scrutiny by Chinese regulators for suspected violations of the country's anti-monopoly laws", 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Quartz India', 'title': 'Ex-Intel CEO Pat Gelsinger may get more than $10 million in severance pay', 'description': 'Outgoing Intel CEO Pat Gelsinger is set to get paid as much as $10 million as he exits the struggling tech giant.Read more...', 'polarity': 0.35}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Hackaday', 'title': 'Finally Putting the RK1 Through its Paces', 'description': 'The good folks at Turing Pi sent me a trio of RK1 modules to put through their paces, to go along with the single unit I bought myself. And the TLDR, if you need some real ARM processing power, and…', 'polarity': 0.27619047619047615}
# Sent to Kafka (news-topic): {'date': '2024-12-06', 'source': 'VentureBeat', 'title': 'Aethir and partners pour $40M into decentralized infrastructure for AI and blockchain', 'description': 'Aethir, which under-used graphics processing units (GPUs) to decentralized companies, announced a $40 million initiative to launch TACOM.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'CNET', 'title': 'Intel Rolls Out Its Lunar Lake-Generation Xe2 Graphics to Arc B-series Cards', 'description': 'The company is targeting 1440p gaming and entry-level ray tracing performance with its Arc B580 and Arc B570 GPUs.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-07', 'source': 'Itainews.com', 'title': '他人の電子マネー40万円タブレット買ったママ友2人逮捕。40万円ってnvidiaのグラボでも刺さってんの？', 'description': '1 ：名無しさん＠涙目です。：2024/12/06(金) 14:03:33.43 ID:npr6rSue0●.net \n\n\n\n\n\n\n\n\n\n保育園のママ友ふたり\u3000他人の電子マネーで約40万円のタブレット購入\u3000詐欺疑いで逮捕 https://t.co/xsRYhKAmMm— TBS NEWS DIG Powered by JNN (@tbsnewsdig) December 6, 2024 \n...', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'CNET', 'title': 'Nintendo Switch 2 Accessories Leaked by Chinese Retailer, Report Says', 'description': "If they're accurate, they give us an idea of the changes made to the upgraded handheld console.", 'polarity': 0.4000000000000001}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Windows Central', 'title': "I just upgraded my GPU, but Indiana Jones and the Great Circle's PC requirements are still making me sweat with their eye-watering demands", 'description': 'The system requirements and recommended PC specs for Indiana Jones and the Great Circle are incredibly steep.', 'polarity': 0.8500000000000001}
# Sent to Kafka (news-topic): {'date': '2024-12-08', 'source': 'TechRadar', 'title': 'Valve could be working on a rival to the Nvidia Shield streaming box', 'description': 'The Nvidia Shield has always been popular with its users, and Valve may be looking to make something similar.', 'polarity': 0.3}
# Sent to Kafka (news-topic): {'date': '2024-12-07', 'source': 'TechRadar', 'title': "Nvidia almost produced an x86 CPU to rival AMD and Intel, but was forced to move to Arm due to 'certain legal issues'", 'description': "Nvidia almost produced an x86 CPU to rival Intel, but was forced to move to Arm due to 'legal issues'.", 'polarity': -0.07500000000000001}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': 'Phoronix', 'title': 'NVIDIA 565.77 Linux Driver Released As First Stable R565 Build', 'description': 'For the past month and a half the NVIDIA R565 Linux driver series has been in public beta with a number of (X)Wayland improvements, DMA-BUF enhancements, VKD3D fixes, and a variety of other enhancements. Today the NVIDIA 565.77 Linux driver was released as th…', 'polarity': -0.13541666666666666}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'GameSpot', 'title': 'New Video Claims NZXT PC Rental Program Is "A Scam," Company Says It\'s Looking Into It', 'description': 'A new report alleges that PC hardware company NZXT\'s PC rental program is "shady and manipulative." The video from Gamers Nexus (via The Verge) accuses NZXT of changing prices and parts between "purchase" and "rental" versions of prebuilt PCs with the same (o…', 'polarity': -0.03787878787878788}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'GameSpot', 'title': "Nintendo Switch 2 'Leak' Could Offer A Very Blurry First-Look At The Console", 'description': 'A low-quality video of what appears to be a Nintendo Switch 2 has emerged, prompting fan speculation over the as-yet-unseen console and the validity of this footage.The video was posted on Chinese video site Bibli and was first spotted by Nintendo Soup (via K…', 'polarity': 0.125}
# Sent to Kafka (news-topic): {'date': '2024-12-02', 'source': 'Quartz India', 'title': "Intel stock climbs over 4% after Pat Gelsinger's retirement", 'description': 'Intel (INTC) shares climbed by over 4% during mid-day trading on Monday after the company announced that its chief executive is out.Read more...', 'polarity': 0.5}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Forbes', 'title': 'Ex-Dividend Reminder: NVIDIA, Qualcomm And NXP Semiconductors', 'description': 'On 12/5/24, NVIDIA, Qualcomm, and NXP Semiconductors will all trade ex-dividend for their respective upcoming dividends.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-08', 'source': 'Forbes', 'title': 'I’ve Looked At Clouds From Both Sides Now: AI For Climate Science', 'description': 'Mike Pritchard from Nvidia takes us through some of the challenges and capabilities of AI for climate.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-05', 'source': "Tom's Hardware UK", 'title': 'TSMC is reportedly in talks with Nvidia to make Blackwell GPUs in Arizona — Blackwell silicon needs to be shipped back to Taiwan for assembly', 'description': "If TSMC reaches a deal with Nvidia, it could reportedly produce Nvidia's Blackwell GPUs at its Fab 21 in Arizona.", 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Business Insider', 'title': 'Stock market today: Rally stalls as Nvidia slips and investors await latest inflation data', 'description': '"Recent Fed speak suggests it will be a live meeting and cuts beyond December aren\'t a guarantee," Bank of America said.', 'polarity': 0.06818181818181818}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'Biztoc.com', 'title': 'Intel Was a Tech Titan, Its Downfall Sends a Warning to Apple, Nvidia, Alphabet', 'description': 'Intel Was a Tech Titan, Its Downfall Sends a Warning to Apple, Nvidia, Alphabet.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Forbes', 'title': 'Conservative Microsoft Eyes Bitcoin As MicroStrategy And Nvidia Lead', 'description': 'Conservative Microsoft Explores Bitcoin Investment While MicroStrategy and Nvidia Drive Crypto Innovation Students of history know that even the most iconoclastic revo...', 'polarity': 0.5}
# Sent to Kafka (news-topic): {'date': '2024-12-03', 'source': 'TechRadar', 'title': 'AMD RX 8800 XT could match RTX 4080’s performance – and easily outgun Nvidia’s GPU for ray tracing', 'description': 'Has AMD fixed ray tracing with RDNA 4 GPUs? Rumor suggests RX 8800 XT could equal Nvidia RTX 4080 Super for ray tracing.', 'polarity': 0.14444444444444446}
# Sent to Kafka (news-topic): {'date': '2024-12-09', 'source': 'Forbes', 'title': 'Nvidia Shares Slide After China Starts Antitrust Probe', 'description': 'Beijing announced it was opening an investigation into Nvidia’s acquisition of Mellanox Technologies.', 'polarity': 0.0}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'Phoronix', 'title': 'NVIDIA vs. AMD GPU Workstation Performance For Blender 4.3', 'description': "With the recent release of Blender 4.3 for this leading open-source 3D modeling software, I've been carrying out some fresh NVIDIA vs. AMD GPU benchmarks for accelerated rendering across several different popular benchmark scenes.", 'polarity': 0.18}
# Sent to Kafka (news-topic): {'date': '2024-12-04', 'source': 'PC Gamer', 'title': "Intel's Arc graphics cards have made their first appearance in the Steam hardware survey just as I'm getting genuinely excited about the new Battlemage B580 card", 'description': 'Dare we hope for some real competition for Nvidia?', 'polarity': 0.2}
